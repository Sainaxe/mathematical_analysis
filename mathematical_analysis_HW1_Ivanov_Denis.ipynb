# %% [markdown]
# ### Ivanov Denis HW№1

# %% [markdown]
# ### Тема “Введение в математический анализ”

# %% [markdown]
# #### 2. Прочитать высказывания математической логики, построить их отрицания и *установить истинность

# %% [markdown]
# ###### 1. Для любого y от 0 до 1, сигнум равен 1. Отрицание: не равен 1.
# ###### 2. Для любого натурального числа n, большего 2, существуют такие натуральные x, y и z, при которых x в степени n равен сумме y в степени n и z в степени n. Отрицание: не равен.
# ###### 3. Для любого вещественного числа x существует вещественное число X, которое больше x. Отрицание: меньше либо равен.
# ###### 4. Для любого комплексного x не существует комплексного y, при котором x больше y или x меньше y. Отрицание: при котором x меньше либо равен y или x больше либо равен y.
# ###### 5. Для любого y от 0 до pi/2 существует epsilon больше 0, при котором sin(y) < sin(y + epsilon). Отрицанеи: при котором sin(y) более либо равен sin(y + epsilon).
# ###### 6. Для любого y от 0 до pi (не включая pi) существует epsilon больше 0, при котором cos(y) > cos(y + epsilon). Отрицание: при котром cos(y) менее либо равен cos(y + epsilon).
# ###### 7. Существует x, не принадлежащий множествам натуральных, целых, рациональных, вещественных и комплексных чисел. Отрицание: любой х принадлежит к множествам натуральных, целых, рациональных, вещественных и комплексных чисел.

# %% [markdown]
# ### Тема “Множество”

# %% [markdown]
# #### Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств. Выполнять на Python.

# %%
import numpy as np
import random
import math
import itertools
from sympy import factorial

# %%
random.seed(42)
a = set([random.randint(-999, 999) for _ in range(random.randint(1, 10))])
b = set([random.randint(-999, 999) for _ in range(random.randint(1, 10))])
c = set([random.randint(-999, 999) for _ in range(random.randint(1, 10))])

# %%
print(f'a: {a}')
print(f'b: {b}')
print(f'c: {c}')
# Out:
# a: {-948, 519}
# b: {-542, -790, -498, -714, 509}
# c: {35, -552, -821, 210, -523, -938, -808, -135, -934}

# %%
sets = {
    'a': a,
    'b': b,
    'c': c
}

# %%
for combination in itertools.combinations(sets.keys(), 2):
    x, y = combination[0], combination[1]
    print(f'Множества: {x}, {y}')
    print(f'x: {sets[x]},\ny: {sets[y]}')
    print(f'Объединение {x} | {y}: {sets[x] | sets[y]}')
    print(f'Пересечение {x} & {y}: {sets[x] & sets[y]}')
    print(f'Разность {x} - {y}: {sets[x] - sets[y]}')
    print(f'Симметрическая разность {x} ^ {y}: {sets[x] ^ sets[y]}')
    cartesian = []
    for item in itertools.product(sets[x], sets[y]):
        cartesian.append(item)
    print(f'Декартово произведение {x} * {y}: {set(cartesian)}')
    print()
# Out:
# Множества: a, b
# x: {-948, 519},
# y: {-542, -790, -498, -714, 509}
# Объединение a | b: {-542, -714, 519, -790, -948, 509, -498}
# Пересечение a & b: set()
# Разность a - b: {-948, 519}
# Симметрическая разность a ^ b: {-542, -714, 519, -790, -948, 509, -498}
# Декартово произведение a * b: {(-948, 509), (-948, -790), (519, 509), (519, -542), (-948, -498), (519, -790), (519, -498), (-948, -714), (519, -714), (-948, -542)}
#
# Множества: a, c
# x: {-948, 519},
# y: {35, -552, -821, 210, -523, -938, -808, -135, -934}
# Объединение a | c: {35, 519, -821, -948, 210, -523, -938, -552, -135, -934, -808}
# Пересечение a & c: set()
# Разность a - c: {-948, 519}
# Симметрическая разность a ^ c: {35, -552, 519, -821, -948, 210, -523, -938, -808, -135, -934}
# ...
